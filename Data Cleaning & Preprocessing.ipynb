# %%
import pandas as pd
import json
import numpy as np


def flatten_json(y):
    out = {}

    def flatten(x, name=''):
        if type(x) is dict:
            for a in x:
                flatten(x[a], name + a + '_')
        elif type(x) is list:
            i = 0
            for a in x:
                flatten(a, name)
                i += 1
        else:
            out[name[:-1]] = x

    flatten(y)
    return out

def export_json(path, output_file):
    final = []

    for line in open(path, 'r'):
        final.append(flatten_json((json.loads(line))))
    new_df = pd.DataFrame(final)
    new_df.to_csv(output_file, index=False)

# %%
files = ['brands.json', 'receipts.json', 'users.json']
output_files = ['brands.csv', 'receipts.csv', 'users.csv']


for f, b in zip(files, output_files):
    export_json(f, b)

# %%
df_receipts = pd.read_csv("/Users/drishtigugal/Desktop/Company/Coding/FetchRewardsDataAnalyst/receipts.csv")
df_brands = pd.read_csv("/Users/drishtigugal/Desktop/Company/Coding/FetchRewardsDataAnalyst/brands.csv")
df_users = pd.read_csv("/Users/drishtigugal/Desktop/Company/Coding/FetchRewardsDataAnalyst/users.csv")

# %% [markdown]
# # EDA

# %%
df_receipts.head()
# Out:
#                    _id_$oid  bonusPointsEarned  \
# 0  5ff1e1eb0a720f0523000575              500.0
# 1  5ff1e1bb0a720f052300056b              150.0
# 2  5ff1e1f10a720f052300057a                5.0
# 3  5ff1e1ee0a7214ada100056f                5.0
# 4  5ff1e1d20a7214ada1000561                5.0
#
#                              bonusPointsEarnedReason  createDate_$date  \
# 0  Receipt number 2 completed, bonus point schedu...     1609687531000
# 1  Receipt number 5 completed, bonus point schedu...     1609687483000
# 2                         All-receipts receipt bonus     1609687537000
# 3                         All-receipts receipt bonus     1609687534000
# 4                         All-receipts receipt bonus     1609687506000
#
#    dateScanned_$date  finishedDate_$date  modifyDate_$date  \
# 0      1609687531000        1.609688e+12     1609687536000
# 1      1609687483000        1.609687e+12     1609687488000
# 2      1609687537000                 NaN     1609687542000
# ...

# %%
# Checking the data type
df_receipts.dtypes
# Out:
# _id_$oid                                                      object
# bonusPointsEarned                                            float64
# bonusPointsEarnedReason                                       object
# createDate_$date                                               int64
# dateScanned_$date                                              int64
# finishedDate_$date                                           float64
# modifyDate_$date                                               int64
# pointsAwardedDate_$date                                      float64
# pointsEarned                                                 float64
# purchaseDate_$date                                           float64
# purchasedItemCount                                           float64
# rewardsReceiptItemList_barcode                                object
# rewardsReceiptItemList_description                            object
# rewardsReceiptItemList_finalPrice                            float64
# ...

# %%
# Total number of rows and columns
df_receipts.shape
# Out:
# (1119, 48)

# %%
# Finding the null values
print(df_receipts.isnull().sum())
# Out:
# _id_$oid                                                        0
# bonusPointsEarned                                             575
# bonusPointsEarnedReason                                       575
# createDate_$date                                                0
# dateScanned_$date                                               0
# finishedDate_$date                                            551
# modifyDate_$date                                                0
# pointsAwardedDate_$date                                       582
# pointsEarned                                                  510
# purchaseDate_$date                                            448
# purchasedItemCount                                            484
# rewardsReceiptItemList_barcode                                526
# rewardsReceiptItemList_description                            525
# rewardsReceiptItemList_finalPrice                             454
# ...

# %%
df_brands.head()
# Out:
#                    _id_$oid       barcode        category      categoryCode  \
# 0  601ac115be37ce2ead437551  511111019862          Baking            BAKING
# 1  601c5460be37ce2ead43755f  511111519928       Beverages         BEVERAGES
# 2  601ac142be37ce2ead43755d  511111819905          Baking            BAKING
# 3  601ac142be37ce2ead43755a  511111519874          Baking            BAKING
# 4  601ac142be37ce2ead43755e  511111319917  Candy & Sweets  CANDY_AND_SWEETS
#
#                cpg_$id_$oid cpg_$ref                       name topBrand  \
# 0  601ac114be37ce2ead437550     Cogs  test brand @1612366101024    False
# 1  5332f5fbe4b03c9a25efd0ba     Cogs                  Starbucks    False
# 2  601ac142be37ce2ead437559     Cogs  test brand @1612366146176    False
# 3  601ac142be37ce2ead437559     Cogs  test brand @1612366146051    False
# 4  5332fa12e4b03c9a25efd1e7     Cogs  test brand @1612366146827    False
#
#                        brandCode
# 0                            NaN
# ...

# %%
# Checking the data type
df_brands.dtypes
# Out:
# _id_$oid        object
# barcode          int64
# category        object
# categoryCode    object
# cpg_$id_$oid    object
# cpg_$ref        object
# name            object
# topBrand        object
# brandCode       object
# dtype: object

# %%
# Total number of rows and columns
df_brands.shape
# Out:
# (1167, 9)

# %%
# Finding the null values
df_brands.isnull().sum()
# Out:
# _id_$oid          0
# barcode           0
# category        155
# categoryCode    650
# cpg_$id_$oid      0
# cpg_$ref          0
# name              0
# topBrand        612
# brandCode       269
# dtype: int64

# %%
# Finding the null values
df_users.head().isnull().sum()
# Out:
# _id_$oid             0
# active               0
# createdDate_$date    0
# lastLogin_$date      0
# role                 0
# signUpSource         0
# state                0
# dtype: int64
